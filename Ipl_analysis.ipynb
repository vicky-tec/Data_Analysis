# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
ipl=pd.read_csv('matches.csv')

# %%
ipl.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
ipl.shape
# Out:
# (636, 18)

# %%
ipl['player_of_match'].value_counts()
# Out:
# player_of_match
# CH Gayle             18
# YK Pathan            16
# DA Warner            15
# AB de Villiers       15
# RG Sharma            14
#                      ..
# SA Yadav              1
# Mustafizur Rahman     1
# CR Brathwaite         1
# A Zampa               1
# BCJ Cutting           1
# Name: count, Length: 201, dtype: int64

# %%
ipl['player_of_match'].value_counts()[0:11]
# Out:
# player_of_match
# CH Gayle          18
# YK Pathan         16
# DA Warner         15
# AB de Villiers    15
# RG Sharma         14
# SK Raina          14
# MS Dhoni          13
# G Gambhir         13
# MEK Hussey        12
# AM Rahane         12
# V Kohli           11
# Name: count, dtype: int64

# %%
ipl['player_of_match'].value_counts()[0:5]
# Out:
# player_of_match
# CH Gayle          18
# YK Pathan         16
# DA Warner         15
# AB de Villiers    15
# RG Sharma         14
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,6))
plt.bar(list(ipl['player_of_match'].value_counts()[0:5].keys()),list(ipl['player_of_match'].value_counts()[0:5]),color=['b','g','y','orange','purple'])
# plt.ylabel('Player of match')
plt.xlabel("Player's Name ")
plt.show()

# %%
ipl['result'].value_counts()
# Out:
# result
# normal       626
# tie            7
# no result      3
# Name: count, dtype: int64

# %%
ipl['toss_winner'].value_counts()
# Out:
# toss_winner
# Mumbai Indians                 85
# Kolkata Knight Riders          78
# Delhi Daredevils               72
# Royal Challengers Bangalore    70
# Kings XI Punjab                68
# Chennai Super Kings            66
# Rajasthan Royals               63
# Deccan Chargers                43
# Sunrisers Hyderabad            35
# Pune Warriors                  20
# Gujarat Lions                  15
# Kochi Tuskers Kerala            8
# Rising Pune Supergiants         7
# Rising Pune Supergiant          6
# Name: count, dtype: int64

# %%
batting_first=ipl[ipl['win_by_runs']!=0]

# %%
batting_first.head()
# Out:
#     id  season       city        date                        team1  \
# 0    1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 4    5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 8    9    2017       Pune  2017-04-11             Delhi Daredevils
# 13  14    2017    Kolkata  2017-04-15        Kolkata Knight Riders
# 14  15    2017      Delhi  2017-04-15             Delhi Daredevils
#
#                           team2                  toss_winner toss_decision  \
# 0   Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 4              Delhi Daredevils  Royal Challengers Bangalore           bat
# 8        Rising Pune Supergiant       Rising Pune Supergiant         field
# 13          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 14              Kings XI Punjab             Delhi Daredevils           bat
#
#     result  dl_applied                       winner  win_by_runs  \
# ...

# %%
plt.figure(figsize=(7,7))
plt.hist(batting_first['win_by_runs'])
plt.title("WIN BY RUNS")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
batting_first["winner"].value_counts()
# Out:
# winner
# Mumbai Indians                 47
# Chennai Super Kings            46
# Kings XI Punjab                32
# Kolkata Knight Riders          31
# Royal Challengers Bangalore    30
# Sunrisers Hyderabad            23
# Rajasthan Royals               23
# Delhi Daredevils               21
# Deccan Chargers                18
# Pune Warriors                   6
# Rising Pune Supergiant          5
# Kochi Tuskers Kerala            2
# Rising Pune Supergiants         2
# Gujarat Lions                   1
# Name: count, dtype: int64

# %%
batting_first['toss_winner'].value_counts()
# Out:
# toss_winner
# Mumbai Indians                 41
# Chennai Super Kings            38
# Kolkata Knight Riders          35
# Delhi Daredevils               34
# Royal Challengers Bangalore    32
# Kings XI Punjab                25
# Rajasthan Royals               25
# Deccan Chargers                22
# Sunrisers Hyderabad            14
# Pune Warriors                  12
# Gujarat Lions                   4
# Rising Pune Supergiants         3
# Rising Pune Supergiant          1
# Kochi Tuskers Kerala            1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(7,7))
plt.pie(list(batting_first["winner"].value_counts()),labels=list(batting_first['winner'].value_counts().keys()),autopct='%0.1f%%')
plt.show()

# %%
plt.figure(figsize=(13,6))
plt.bar(list(batting_first['winner'].value_counts()[0:5].keys()),list(batting_first['winner'].value_counts()[0:5]),color=['blue','Red','yellow'])
plt.show()

# %%
ipl['venue'].value_counts()
# Out:
# venue
# M Chinnaswamy Stadium                                   66
# Eden Gardens                                            61
# Feroz Shah Kotla                                        60
# Wankhede Stadium                                        57
# Rajiv Gandhi International Stadium, Uppal               49
# MA Chidambaram Stadium, Chepauk                         48
# Punjab Cricket Association Stadium, Mohali              35
# Sawai Mansingh Stadium                                  33
# Dr DY Patil Sports Academy                              17
# Subrata Roy Sahara Stadium                              17
# Maharashtra Cricket Association Stadium                 15
# Kingsmead                                               15
# Sardar Patel Stadium, Motera                            12
# SuperSport Park                                         12
# Brabourne Stadium                                       11
# Punjab Cricket Association IS Bindra Stadium, Mohali    11
# ...

# %%
venue=ipl[ipl['win_by_runs']!=0]

# %%
venue.head()
# Out:
#     id  season       city        date                        team1  \
# 0    1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 4    5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 8    9    2017       Pune  2017-04-11             Delhi Daredevils
# 13  14    2017    Kolkata  2017-04-15        Kolkata Knight Riders
# 14  15    2017      Delhi  2017-04-15             Delhi Daredevils
#
#                           team2                  toss_winner toss_decision  \
# 0   Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 4              Delhi Daredevils  Royal Challengers Bangalore           bat
# 8        Rising Pune Supergiant       Rising Pune Supergiant         field
# 13          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 14              Kings XI Punjab             Delhi Daredevils           bat
#
#     result  dl_applied                       winner  win_by_runs  \
# ...

# %%
plt.figure(figsize=(7,7))
plt.hist(venue['win_by_runs'],bins=30)
plt.show()

# %%
batting_second['winner'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 batting_second['winner'].value_counts()
#
# NameError: name 'batting_second' is not defined

# %%
                    #Making a bar plot for top-3 teams with most wins after batting second
plt.figure(figsize=(7,5))
plt.bar(list(batting_second['winner'].value_counts()[0:3].keys()),list(batting_second['winner'].value_counts()[0:3]),color=["blue","green","orange"])
plt.show()

# %%
ipl['season'].value_counts()
# Out:
# season
# 2013    76
# 2012    74
# 2011    73
# 2014    60
# 2016    60
# 2010    60
# 2015    59
# 2017    59
# 2008    58
# 2009    57
# Name: count, dtype: int64

# %%
ipl['city'].value_counts()
# Out:
# city
# Mumbai            85
# Bangalore         66
# Kolkata           61
# Delhi             60
# Hyderabad         49
# Chennai           48
# Chandigarh        46
# Jaipur            33
# Pune              32
# Durban            15
# Centurion         12
# Ahmedabad         12
# Visakhapatnam     11
# Rajkot            10
# Dharamsala         9
# Johannesburg       8
# Cape Town          7
# Port Elizabeth     7
# Ranchi             7
# Abu Dhabi          7
# Cuttack            7
# Raipur             6
# Sharjah            6
# Indore             5
# Kochi              5
# Kanpur             4
# East London        3
# Kimberley          3
# Nagpur             3
# Bloemfontein       2
# Name: count, dtype: int64

# %%
sum(ipl['toss_winner']==ipl['winner'])
# Out:
# 325

# %%
325/636
# Out:
# 0.5110062893081762

# %%
#continue tommrow...... 10/01/25

# %%
ipl.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
for reel in ipl.result:
    print(reel)
# Out:
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# tie
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# normal
# ...

# %%
ipl['result'].value_counts()
# Out:
# result
# normal       626
# tie            7
# no result      3
# Name: count, dtype: int64

# %%
plt.Figure(figsize=(4,4))
plt.bar(list(ipl['result'].value_counts()[0:5].keys()),list(ipl['result'].value_counts()[0:5]),color=['green','red','yellow'])
plt.show()

# %%
batting_first['city'].value_counts()
# Out:
# city
# Mumbai            42
# Chennai           30
# Delhi             28
# Bangalore         27
# Kolkata           25
# Hyderabad         20
# Chandigarh        20
# Pune              16
# Jaipur            10
# Durban             9
# Visakhapatnam      7
# Ahmedabad          6
# Dharamsala         5
# Cuttack            4
# Cape Town          4
# Centurion          4
# Port Elizabeth     3
# Rajkot             3
# Johannesburg       3
# Kochi              3
# Abu Dhabi          3
# Nagpur             2
# East London        2
# Raipur             2
# Ranchi             2
# Sharjah            2
# Kimberley          1
# Bloemfontein       1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(7,155))
plt.pie(list(batting_first["city"].value_counts()),labels=list(batting_first['city'].value_counts().keys()),autopct='%0.1f%%')
plt.show()

# %%
batting_first=ipl[ipl['win_by_wickets']!=0]

# %%
batting_first.head()
# Out:
#    id  season       city        date                   team1  \
# 1   2    2017       Pune  2017-04-06          Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07           Gujarat Lions
# 3   4    2017     Indore  2017-04-08  Rising Pune Supergiant
# 5   6    2017  Hyderabad  2017-04-09           Gujarat Lions
# 6   7    2017     Mumbai  2017-04-09   Kolkata Knight Riders
#
#                     team2             toss_winner toss_decision  result  \
# 1  Rising Pune Supergiant  Rising Pune Supergiant         field  normal
# 2   Kolkata Knight Riders   Kolkata Knight Riders         field  normal
# 3         Kings XI Punjab         Kings XI Punjab         field  normal
# 5     Sunrisers Hyderabad     Sunrisers Hyderabad         field  normal
# 6          Mumbai Indians          Mumbai Indians         field  normal
#
#    dl_applied                  winner  win_by_runs  win_by_wickets  \
# 1           0  Rising Pune Supergiant            0               7
# ...

# %%
plt.Figure(figsize=(3,3))
plt.hist(batting_first['win_by_wickets'],bins=30)
# plt.hist(list(ipl['win_by_wickets'].value_counts()[0:5].keys()),list(ipl['win_by_wickets'].value_counts()[0:5]),color=['g','r','b','purple'])
# plt.xlabel('wicket')
# plt.ylabel("Run's")
plt.show()
